# %%
import pandas as pd
import numpy as np
import os

# %%
file_path='C:\\Users\\charles\\Desktop\\Jupiter\\tutorial_py\\pandas\\Assignment\\911.txt'
df = pd.read_csv(file_path)
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %% [markdown]
# ### task 1. description for categorical and numerical data

# %%
# numerical
df.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %%
# getting categoriacal data
categorical_data_index = df.dtypes[df.dtypes == 'object'].index
categorical_data_index
# Out:
# Index(['desc', 'title', 'timeStamp', 'twp', 'addr'], dtype='object')

# %%
df[categorical_data_index].describe()
# Out:
#                                                      desc  \
# count                                               99492
# unique                                              99455
# top     GREEN ST & E BASIN ST;  NORRISTOWN; Station 30...
# freq                                                    4
#
#                               title            timeStamp           twp  \
# count                         99492                99492         99449
# unique                          110                72577            68
# top     Traffic: VEHICLE ACCIDENT -  2015-12-10 17:40:01  LOWER MERION
# freq                          23066                    8          8443
#
#                                      addr
# count                               98973
# unique                              21914
# top     SHANNONDELL DR & SHANNONDELL BLVD
# freq                                  938

# %%
# typecasting the latitude column into an interger because it is a float
df['lat'] = df['lat'].apply(lambda i: int(i))

# %%
df.head(5)
# Out:
#    lat        lng                                               desc      zip  \
# 0   40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1   40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2   40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3   40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4   40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
#
#                      title            timeStamp                twp  \
# 0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# ...

# %%
# group by latitude
df.groupby('lat').describe()
# Out:
#          lng                                                                   \
#        count       mean       std        min        25%        50%        75%
# lat
# 30       1.0 -95.595595       NaN -95.595595 -95.595595 -95.595595 -95.595595
# 32       1.0 -86.276106       NaN -86.276106 -86.276106 -86.276106 -86.276106
# 39    1477.0 -75.274185  0.336397 -84.395256 -75.274479 -75.258430 -75.253165
# 40   98012.0 -75.317781  0.154427 -77.686813 -75.395558 -75.306233 -75.208279
# 41       1.0 -76.874030       NaN -76.874030 -76.874030 -76.874030 -76.874030
#
#                     zip                ...                          e       \
#            max    count          mean  ...      75%      max    count mean
# lat                                    ...
# 30  -95.595595      1.0  77316.000000  ...  77316.0  77316.0      1.0  1.0
# 32  -86.276106      1.0  36107.000000  ...  36107.0  36107.0      1.0  1.0
# ...

# %%
df_1 = df.groupby('lat').describe().transpose()
df_1
# Out:
# lat                  30            32            39            40           41
# lng count      1.000000      1.000000   1477.000000  98012.000000      1.00000
#     mean     -95.595595    -86.276106    -75.274185    -75.317781    -76.87403
#     std             NaN           NaN      0.336397      0.154427          NaN
#     min      -95.595595    -86.276106    -84.395256    -77.686813    -76.87403
#     25%      -95.595595    -86.276106    -75.274479    -75.395558    -76.87403
#     50%      -95.595595    -86.276106    -75.258430    -75.306233    -76.87403
#     75%      -95.595595    -86.276106    -75.253165    -75.208279    -76.87403
#     max      -95.595595    -86.276106    -75.209714    -74.995041    -76.87403
# zip count      1.000000      1.000000   1415.000000  85219.000000      1.00000
#     mean   77316.000000  36107.000000  19100.174558  19239.079079  17752.00000
#     std             NaN           NaN     37.688422    279.214889          NaN
# ...

# %%
type(df_1.loc['lng'])
# Out:
# pandas.core.frame.DataFrame

# %%
# this is the count of latitude 40
df_1.loc['lng'].loc['count', 40]
# Out:
# 98012.0

# %%
df.head(4)
# Out:
#    lat        lng                                               desc      zip  \
# 0   40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1   40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2   40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3   40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
#
#                      title            timeStamp                twp  \
# 0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1
# 3          AIRY ST & SWEDE ST  1

# %%
# finding people from the same zip location

# %%
# timestamp datatype and extract day on a new column

# %%
# datatype
df['timeStamp'].dtype    # datatype of timestamp is an object
# Out:
# dtype('O')

# %%
# check the timestamp data and extract a day on a new column

# %% [markdown]
# ## 5. filter out a zip code whose address starts with an a

# %%
df.head(5)
# Out:
#    lat        lng                                               desc      zip  \
# 0   40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1   40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2   40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3   40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4   40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
#
#                      title            timeStamp                twp  \
# 0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# ...

# %%
l = []
for i in df['addr'].astype(str):
    if i[0] == 'A':
        print(i)
        
l
# Out:
# AIRY ST & SWEDE ST
# ALLENDALE RD & WILLS BLVD
# AUTO PARK BLVD & LINFIELD TRAPPE RD
# AVIGNON DR & DEAD END
# ADAMS ST & WALNUT ST
# ASHBOURNE RD & ROWLAND AVE
# AIRY ST & TREMONT AVE
# ARBOUR GREEN CIR & CLOVER LEAF LN
# ARBOUR GREEN CIR & CLOVER LEAF LN
# ARDMORE AVE & W ATHENS AVE
# ALLENTOWN RD & BREEZEWOOD LN
# ASTOR ST & W AIRY ST
# AVENUE A  & SILL AVE
# ABINGTON AVE & CHARLES ST
# AIRY ST & HIGH ALY
# ASPEN WAY & VILLAGE DR
# ASHFORD LN & SKIPPACK PIKE
# ARGYLE AVE & S BETHLEHEM PIKE
# AIRY ST & HIGH ALY
# ARBORDALE CIR & BENNINGTON DR
# ASTOR ST & WARREN ST
# ASHBOURNE RD & SPRING AVE
# ARDEN RD & JOEL DR
# ASHBOURNE RD & SPRING AVE
# AIRY ST & GEORGE ST
# ARGYLE RD & ST PAULS RD
# ALISON RD & BLAIR MILL RD
# ALEXANDER DR & BERGEY RD
# ARCH ST & E MARSHALL ST
# ARCH ST & E BASIN ST
# ASTOR ST & W BLACKBERRY ALY
# ALLENTOWN RD & WOODLAWN DR
# ARBORETUM RD & LORIMER DR
# ALLENTOWN RD & BARNDT RD
# ALLENTOWN RD & BARNDT RD
# ALLENTOWN RD & BARNDT RD
# ...
