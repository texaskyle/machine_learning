# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
draft1 = pd.DataFrame(iris.data, columns = iris.feature_names)

# %%
draft1.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# reading a csv file using a the format of reading  a tsv(pd.read_table('____'))
df1 = pd.read_table('C:\\Users\\charles\\Desktop\\Jupiter\\data.csv',sep=',', header=None,names=["a","b","c","d","e","f"])

# %%
df1.head(4)
# Out:
#      a           b           c       d       e    f
# 0  NaN         Car       Model  Volume  Weight  CO2
# 1  0.0      Toyoty        Aygo    1000     790   99
# 2  1.0  Mitsubishi  Space Star    1200    1160   95
# 3  2.0       Skoda      Citigo    1000     929   95

# %%
# creating a pandas dataframe using a  list of lists
df2 = pd.DataFrame([[1, "Lucy", "1N", "Maths"],
                   [2, "Evans", "2k", "Physics"],
                   [3, "jane", "4j", "CRE"],
                   [4, "Njoro", "3p", "kiswa"],
                   [5,"kezz", "2j", "Eng"]],
                  columns = ['Position', "Name", "Class", "Subject"])

# %%
# creating a dataframe using dictonaries
import pandas as pd
data = pd.DataFrame([{"name": "ken", "car": "subaru", "pet": "Dog"},
                    {"name": "evans", "car": "Rolls Royce", "hobby": "Football", "pet": "Tiger"},
                    {"name":"kezz", "pet":["cat", "dog"],"sch":"kahuho"}
                    ])

# %%
data
# Out:
#     name          car         pet     hobby     sch
# 0    ken       subaru         Dog       NaN     NaN
# 1  evans  Rolls Royce       Tiger  Football     NaN
# 2   kezz          NaN  [cat, dog]       NaN  kahuho

# %%
df2.head(5)
# Out:
#    Position   Name Class  Subject
# 0         1   Lucy    1N    Maths
# 1         2  Evans    2k  Physics
# 2         3   jane    4j      CRE
# 3         4  Njoro    3p    kiswa
# 4         5   kezz    2j      Eng

# %% [markdown]
# # indexing

# %%
# specifying another column that you want to be the index
df3 = pd.read_csv("C:\\Users\\charles\\Desktop\\Jupiter\\data.csv", index_col=["Car"])
df3
# Out:
#             Unnamed: 0       Model  Volume  Weight  CO2
# Car
# Toyoty               0        Aygo    1000     790   99
# Mitsubishi           1  Space Star    1200    1160   95
# Skoda                2      Citigo    1000     929   95
# Fiat                 3         500     900     865   90
# Mini                 4      Cooper    1500    1140  105
# VW                   5         Up!    1000     929  105
# Skoda                6       Fabia    1400    1109   90
# Mercedes             7     A-Class    1500    1365   92
# Ford                 8      Fiesta    1500    1112   98
# Audi                 9          A1    1600    1150   99
# Hyundai             10         I20    1100     980   99
# Suzuki              11       Swift    1300     990  101
# Ford                12      Fiesta    1000    1112   99
# Honda               13       Civic    1600    1252   94
# Hundai              14         I30    1600    1326   97
# Opel                15       Astra    1600    1330   97
# ...

# %%
df4 = pd.read_csv('Book1.csv', index_col=['key1','key2'])

# %%
df4
# Out:
#            value1  value2
# key1 key2
# one  a          3       7
# one  b          5      45
#      c         63      32
#      d          2       4
# two  a          4       5
#      b          6       2
#      c          4       7
#      d          2       4

# %%
df5 = pd.read_csv("Book2.csv",header=None, skiprows=[0,2,3,5])

# %%
df5
# Out:
#    0  1  2  3       4
# 0  a  b  c  d   evans
# 1  1  2  4  6   njoro
# 2  4  5  7  2  kalucy

# %% [markdown]
# ## isnull()

# %%
df6 = pd.read_csv('Book3.csv')
df6.isnull().sum()
# Out:
# key1      0
# key2      1
# value1    1
# value2    1
# value3    5
# dtype: int64

# %% [markdown]
# ## reading data from the excel file

# %%
# reading content from the sheet one
df7 = pd.read_excel(r"C:\\Users\\charles\\Desktop\\Jupiter\\tutorial_py\\pandas\\Book4.xlsx")

# %%
df7
# Out:
#    key1 key2  value1  value2
# 0  one     a       3       7
# 1   one    b       5      45
# 2   one    c      63      32
# 3   one    d       2       4
# 4   two    a       4       5
# 5   two    b       6       2
# 6   two    c       4       7
# 7   two    d       2       4

# %%
# reading the cotent from the sshet 2
df7  = pd.read_excel("C:\\Users\\charles\\Desktop\\Jupiter\\tutorial_py\\pandas\\Book4.xlsx",sheet_name='phase2')

# %%
df7
# Out:
#    cars      name model   hvfb  gsnb
# 0   1.0  mercedez    BC    bds   NaN
# 1   2.0       NaN   NaN   bdgs  bsdg
# 2  35.0       bus    A1  bdfbs   NaN
# 3   6.0       NaN   NaN    NaN   NaN
# 4   NaN    toyota   NaN    bds   bsd
# 5   8.0       NaN   NaN    NaN  bdgs

# %% [markdown]
# ## read data from url

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)"
df9 = pd.read_html(url)[0]

# %%
type(df9)
# Out:
# pandas.core.frame.DataFrame

# %%
df9.head(5)
# Out:
#   Country / Area UN continentalregion[4] UN statisticalsubregion[4]  \
# 0       China[a]                    Asia               Eastern Asia
# 1          India                    Asia              Southern Asia
# 2  United States                Americas           Northern America
# 3      Indonesia                    Asia         South-eastern Asia
# 4       Pakistan                    Asia              Southern Asia
#
#    Population(1 July 2018)  Population(1 July 2019)  Change
# 0               1427647786               1433783686  +0.43%
# 1               1352642280               1366417754  +1.02%
# 2                327096265                329064917  +0.60%
# 3                267670543                270625568  +1.10%
# 4                212228286                216565318  +2.04%

# %%
df9[['Country / Area', 'Population(1 July 2019)']]
# Out:
#                         Country / Area  Population(1 July 2019)
# 0                             China[a]               1433783686
# 1                                India               1366417754
# 2                        United States                329064917
# 3                            Indonesia                270625568
# 4                             Pakistan                216565318
# ..                                 ...                      ...
# 229  Falkland Islands (United Kingdom)                     3377
# 230                               Niue                     1615
# 231              Tokelau (New Zealand)                     1340
# 232                    Vatican City[z]                      799
# 233                              World               7713468100
#
# [234 rows x 2 columns]

# %%
df9['Population(1 July 2019)']
# Out:
# 0      1433783686
# 1      1366417754
# 2       329064917
# 3       270625568
# 4       216565318
#           ...
# 229          3377
# 230          1615
# 231          1340
# 232           799
# 233    7713468100
# Name: Population(1 July 2019), Length: 234, dtype: int64

# %%
df9[['Population(1 July 2019)']]
# Out:
#      Population(1 July 2019)
# 0                 1433783686
# 1                 1366417754
# 2                  329064917
# 3                  270625568
# 4                  216565318
# ..                       ...
# 229                     3377
# 230                     1615
# 231                     1340
# 232                      799
# 233               7713468100
#
# [234 rows x 1 columns]

# %%
# to see all the column names
df9.columns
# Out:
# Index(['Country / Area', 'UN continentalregion[4]',
#        'UN statisticalsubregion[4]', 'Population(1 July 2018)',
#        'Population(1 July 2019)', 'Change'],
#       dtype='object')

# %%
# reading data from the github
df10 = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv", sep=',')

# %%
df10.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df10[['sepal_length', 'petal_length']].head(5)
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
# knowing the datatype of each column in each dataset
df10.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
## reading a dataset of wineframe
df11 = pd.read_csv("winequality-red.csv", sep=';', skiprows=[1,2,4])

# %% [markdown]
# df11.head(5)

# %%
df11.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.8              0.76         0.04             2.3      0.092
# 1            7.4              0.70         0.00             1.9      0.076
# 2            7.4              0.66         0.00             1.8      0.075
# 3            7.9              0.60         0.06             1.6      0.069
# 4            7.3              0.65         0.00             1.2      0.065
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 15.0                  54.0   0.9970  3.26       0.65
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                 13.0                  40.0   0.9978  3.51       0.56
# 3                 15.0                  59.0   0.9964  3.30       0.46
# 4                 15.0                  21.0   0.9946  3.39       0.47
#
#    alcohol  quality
# 0      9.8        5
# 1      9.4        5
# 2      9.4        5
# ...

# %%
df11.tail(2)
# Out:
#       7.4    0.7     0  1.9  0.076    11    34   0.9978  3.51  0.56   9.4  5
# 1594  5.9  0.645  0.12  2.0  0.075  32.0  44.0  0.99547  3.57  0.71  10.2  5
# 1595  6.0  0.310  0.47  3.6  0.067  18.0  42.0  0.99549  3.39  0.66  11.0  6

# %%
type(df11)
# Out:
# pandas.core.frame.DataFrame

# %%
# selecting one column name and printing it
df11['alcohol'].head(5)
# Out:
# 0     9.8
# 1     9.4
# 2     9.4
# 3     9.4
# 4    10.0
# Name: alcohol, dtype: float64

# %%
df11[['fixed acidity']].dtypes
# Out:
# fixed acidity    float64
# dtype: object

# %%
df11[['alcohol']].dtypes
# Out:
# alcohol    float64
# dtype: object

# %%
df11.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# renaming the columns
df11.rename(columns={'alcohol': 'alcohol_percentage'}, inplace=True)

# %%
df11
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.8             0.760         0.04             2.3      0.092
# 1               7.4             0.700         0.00             1.9      0.076
# 2               7.4             0.660         0.00             1.8      0.075
# 3               7.9             0.600         0.06             1.6      0.069
# 4               7.3             0.650         0.00             1.2      0.065
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# saving the changes  to the same csv file
try:
    df11.to_csv('winequality-red.csv', index=False)
except PermissionError:
    print("You have no permission to saving this changes!!")
else:
    print("successfully saved")
# Out:
# successfully saved

# %%
df11.isnull().head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          False             False        False           False      False
# 1          False             False        False           False      False
# 2          False             False        False           False      False
# 3          False             False        False           False      False
# 4          False             False        False           False      False
#
#    free sulfur dioxide  total sulfur dioxide  density     pH  sulphates  \
# 0                False                 False    False  False      False
# 1                False                 False    False  False      False
# 2                False                 False    False  False      False
# 3                False                 False    False  False      False
# 4                False                 False    False  False      False
#
#    alcohol_percentage  quality
# 0               False    False
# ...

# %%
df11.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol_percentage      0
# quality                 0
# dtype: int64

# %%
df11
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.8             0.760         0.04             2.3      0.092
# 1               7.4             0.700         0.00             1.9      0.076
# 2               7.4             0.660         0.00             1.8      0.075
# 3               7.9             0.600         0.06             1.6      0.069
# 4               7.3             0.650         0.00             1.2      0.065
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# in this case the entire dataset wont be loaded, only the specified number of rows will be loaded, thus not memory intensive
df12 = pd.read_csv('C:\\Users\\charles\\Desktop\\Jupiter\\tutorial_py\\pandas\\winequality-red.csv', nrows=7)

# %%
df12
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.8              0.76         0.04             2.3      0.092
# 1            7.4              0.70         0.00             1.9      0.076
# 2            7.4              0.66         0.00             1.8      0.075
# 3            7.9              0.60         0.06             1.6      0.069
# 4            7.3              0.65         0.00             1.2      0.065
# 5            7.8              0.58         0.02             2.0      0.073
# 6            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 15.0                  54.0   0.9970  3.26       0.65
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                 13.0                  40.0   0.9978  3.51       0.56
# 3                 15.0                  59.0   0.9964  3.30       0.46
# ...

# %% [markdown]
# ## data write operation

# %%
# 1 step is about reading the data
import pandas as pd
df12 = pd.read_csv('Book1.csv')
df12
# Out:
#    key1 key2  value1  value2
# 0  one     a       3       7
# 1   one    b       5      45
# 2   one    c      63      32
# 3   one    d       2       4
# 4   two    a       4       5
# 5   two    b       6       2
# 6   two    c       4       7
# 7   two    d       2       4

# %%
# second step is on writting the file, 
try:
    df12.to_csv('C:/Users/charles/Desktop/Jupiter/tutorial_py/pandas/xyz.csv', index=False)
except PermissionError:
    print("Denied permission!!")
else:
    print("successful")
# Out:
# successful

# %%
# changing the default separator, which is a comma in case of a csv  file
pd.read_csv('C:\\Users\\charles\\Desktop\\Jupiter\\tutorial_py\\pandas\\winequality-red.csv', nrows=6)
try:
    df12.to_csv('C:/Users/charles/Desktop/Jupiter/tutorial_py/pandas/red wine quality.csv', sep='@')
except PermissionError:
    print("Permission denied")
else:
    print("successful")
# Out:
# successful

# %%
# setting the header and the index to false when performing the write file operation
df13 = pd.read_csv('C:\\Users\\charles\\Desktop\\Jupiter\\tutorial_py\\pandas\\red wine quality.csv', sep='@', index_col=['key1'])
df13.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df13
# Out:
#      key2  value1  value2
# key1
# one     a       3       7
# one     b       5      45
# one     c      63      32
# one     d       2       4
# two     a       4       5
# two     b       6       2
# two     c       4       7
# two     d       2       4

# %%
try:
    df13.to_csv('C:/Users/charles/Desktop/Jupiter/tutorial_py/pandas/abc.csv', header=False, index=False, sep='#', na_rep='NULL')
except Exceptions as e:
    print(e)
else:
    print("Successful")
# Out:
# Successful

# %%
df14 = pd.read_csv('C:\\Users\\charles\\Desktop\\Jupiter\\tutorial_py\\pandas\\red wine quality.csv', sep='@')
df14.drop('Unnamed: 0', axis=1, inplace=True)
df14
# Out:
#    key1 key2  value1  value2
# 0  one     a       3       7
# 1   one    b       5      45
# 2   one    c      63      32
# 3   one    d       2       4
# 4   two    a       4       5
# 5   two    b       6       2
# 6   two    c       4       7
# 7   two    d       2       4

# %%
# writing the data using my own column names
#path = 'C:/Users/charles/Desktop/Jupiter/tutorial_py/pandas/abc3.csv'
column_order = ["column_1", "column_2", "column_3", "column_4"]
df14.to_csv('C:/Users/charles/Desktop/Jupiter/tutorial_py/pandas/abc3.csv', index=False, columns=column_order)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2632\1702826359.py in <module>
#       2 #path = 'C:/Users/charles/Desktop/Jupiter/tutorial_py/pandas/abc3.csv'
#       3 column_order = ["column_1", "column_2", "column_3", "column_4"]
# ----> 4 df14.to_csv('C:/Users/charles/Desktop/Jupiter/tutorial_py/pandas/abc3.csv', index=False, columns=column_order)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)'
table = pd.read_html(url)
len(table)
# Out:
# 2

# %%
table[0]
# Out:
#                         Country / Area UN continentalregion[4]  \
# 0                             China[a]                    Asia
# 1                                India                    Asia
# 2                        United States                Americas
# 3                            Indonesia                    Asia
# 4                             Pakistan                    Asia
# ..                                 ...                     ...
# 229  Falkland Islands (United Kingdom)                Americas
# 230                               Niue                 Oceania
# 231              Tokelau (New Zealand)                 Oceania
# 232                    Vatican City[z]                  Europe
# 233                              World                     NaN
#
#     UN statisticalsubregion[4]  Population(1 July 2018)  \
# 0                 Eastern Asia               1427647786
# 1                Southern Asia               1352642280
# ...

# %%
table[1]
# Out:
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteLists of countries by population statistics  \
# 0                                              Global
# 1                               Continents/subregions
# ...

# %%
table[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5740\3400727548.py in <module>
# ----> 1 table[2]
#
# IndexError: list index out of range
