# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style='darkgrid')   # setting the background

# %%
# loading the tips dataset
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# drawing a relation plot
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tips['total_bill'].value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='time', data=tips)

# %%
# using the size column 
sns.relplot(x='total_bill', y='tip', hue='time', style='size', data=tips)

# %%
# size
sns.relplot(x='total_bill', y='tip', hue='smoker', style='time', size='size' ,data=tips)

# %% [markdown]
# ## creating a new dataframe

# %%
import numpy as np
from numpy.random import randn

# %%
df7 = pd.DataFrame(dict(time=np.arange(500), value=randn(500).cumsum()))
df7.head(5)
# Out:
#    time     value
# 0     0  0.118300
# 1     1  0.320853
# 2     2 -0.166809
# 3     3  0.452943
# 4     4 -0.908932

# %%
sns.relplot(x='time', y='value', kind='line', data=df7, sort=True)

# %%
## family dataset
fmri = sns.load_dataset('fmri')
fmri.head(5)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, ci='sd')

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', hue='event' ,style='region', markers=True)

# %% [markdown]
# # col

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips ,col='time', hue='smoker')

# %%
# separating according to size
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', col='size', col_wrap=3, height=3)
